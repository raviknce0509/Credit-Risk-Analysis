# %%
# Loaded variable 'df' from URI: /Users/ravikumarnalawade/Documents/Certifications/Project/GitHub/Credit-Risk-Analysis/data/lcDataSample.csv
import pandas as pd
df = pd.read_csv(r'/Users/ravikumarnalawade/Documents/Certifications/Project/GitHub/Credit-Risk-Analysis/data/lcDataSample.csv')
# Out:
# /var/folders/1y/fk3nmszx1jv_9_cy47zq59dc0000gn/T/ipykernel_72648/1200772756.py:3: DtypeWarning: Columns (47,55,132) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'/Users/ravikumarnalawade/Documents/Certifications/Project/GitHub/Credit-Risk-Analysis/data/lcDataSample.csv')

# %%
columan_names = df.columns

# %%
with open('column_names.txt', 'w') as f:
    for col in df.columns:
        f.write(col + '\n')
